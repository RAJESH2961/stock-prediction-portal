# %%
import pandas as pd

# %%
df = pd.read_csv('call_activity.csv')

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.head(15)
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 0     KS             128        415                 No             Yes
# 1     OH             107        415                 No             Yes
# 2     NJ             137        415                 No              No
# 3     OH              84        408                Yes              No
# 4     OK              75        415                Yes              No
# 5     AL             118        510                Yes              No
# 6     MA             121        510                 No             Yes
# 7     MO             147        415                Yes              No
# 8     LA             117        408                 No              No
# 9     WV             141        415                Yes             Yes
# 10    IN              65        415                 No              No
# 11    RI              74        415                 No              No
# ...

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
type(df) #it is an data frame
# Out:
# pandas.core.frame.DataFrame

# %%
# Collection of series is known as dataframes
type(df['State'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # 🔹 What is a Series in Pandas?
# # A Series is a one-dimensional array-like data structure in Pandas.
# # You can think of it as:
#
# # A single column of data with labeled indices.
#
# # It is similar to a list or a column in an Excel sheet, but more powerful because it has labels (index) and built-in vectorized operations.

# %% [markdown]
# # 📊 What is a DataFrame?
# # A DataFrame is the main data structure in Pandas.
# # Think of it like an Excel spreadsheet or SQL table — it’s a 2D table with:
#
# # Rows (with indices)
#
# # Columns (with names/labels)
#
# # Mixed data types (strings, numbers, dates, etc.)

# %%
# Dataframes
df['Voice mail plan'] ## This is one series
df['Total day calls'] ## This is another series
# Out:
# 0       110.0
# 1       123.0
# 2       114.0
# 3        71.0
# 4       113.0
#         ...
# 3328     77.0
# 3329     57.0
# 3330    109.0
# 3331    105.0
# 3332    113.0
# Name: Total day calls, Length: 3333, dtype: float64

# %% [markdown]
# demo

# %% [markdown]
# # Basic Ops

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# dtype: object

# %%
df.State
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
# df.International plan # syntax error
df['International plan']
# Out:
# 0        No
# 1        No
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 3328     No
# 3329     No
# 3330     No
# 3331    Yes
# 3332     No
# Name: International plan, Length: 3333, dtype: object

# %%
df[['State','Account length', 'Area code', 'International plan']]
# Out:
#      State  Account length  Area code International plan
# 0       KS             128        415                 No
# 1       OH             107        415                 No
# 2       NJ             137        415                 No
# 3       OH              84        408                Yes
# 4       OK              75        415                Yes
# ...    ...             ...        ...                ...
# 3328    AZ             192        415                 No
# 3329    WV              68        415                 No
# 3330    RI              28        510                 No
# 3331    CT             184        510                Yes
# 3332    TN              74        415                 No
#
# [3333 rows x 4 columns]

# %%
# Displayinh unique States
df.State.unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
# Fetching rows with conditions
df[df['International plan'] == 'No']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 6       MA             121        510                 No             Yes
# 8       LA             117        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# Fetching rows with conditions


df[(df['International plan'] == 'No') & (df['Churn'] == False) & (df['Voice mail plan'] == 'No')]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2       NJ             137        415                 No              No
# 8       LA             117        408                 No              No
# 11      RI              74        415                 No              No
# 12      IA             168        408                 No              No
# 13      MT              95        510                 No              No
# ...    ...             ...        ...                ...             ...
# 3325    OH              78        408                 No              No
# 3326    OH              96        415                 No              No
# 3327    SC              79        415                 No              No
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# iloc (index based location)
print("Index based Indexing",df.iloc[12])

# loc(non index based locations)
# Out:
# Index based Indexing State                        IA
# Account length              168
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         104.9
# Total eve calls            71.0
# Total eve charge           8.92
# Total night minutes       141.1
# Total night calls         128.0
# Total night charge         6.35
# Total intl minutes         11.2
# Total intl calls              2
# Total intl charge          3.02
# Customer service calls      1.0
# Churn                     False
# Name: 12, dtype: object

# %% [markdown]
# #### df.iloc[1,1]

# %%
df.iloc[12,1] # row col
# Out:
# np.int64(168)

# %%
# Slicing
df.iloc[10,2]
# Out:
# np.int64(415)

# %%
df.isnull().sum()
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.drop('Total night minutes', axis=1) # axis 0 is row axix 1 is col
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...
